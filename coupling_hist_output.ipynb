# %%
cd /g/data/ik11/inputs/access-om3/0.x.0/1deg/share
# Out:
# /g/data/ik11/inputs/access-om3/0.x.0/1deg/share

# %%
ls
# Out:
# access-om2-1deg-ESMFmesh.nc  access-om2-1deg-nomask-ESMFmesh.nc  topog.nc

# %%
import xarray as xr

# %%
ds = xr.open_dataset('access-om2-1deg-ESMFmesh.nc')

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:         (nodeCount: 108071, coordDim: 2, elementCount: 108000,
#                      maxNodePElement: 4)
# Dimensions without coordinates: nodeCount, coordDim, elementCount,
#                                 maxNodePElement
# Data variables:
#     nodeCoords      (nodeCount, coordDim) float64 ...
#     elementConn     (elementCount, maxNodePElement) int32 ...
#     numElementConn  (elementCount) int32 ...
#     centerCoords    (elementCount, coordDim) float64 ...
#     elementMask     (elementCount) int8 ...
#     elementArea     (elementCount) float64 ...
# Attributes:
#     gridType:       unstructured mesh
#     timeGenerated:  2024-01-25 15:01:40.899669
#     created_by:     ds0092
#     inputFile:      /g/data/ik11/inputs/access-om2/input_20201102/mom_1deg/oc...
#     history:        Created using commit 7b06e94dc79684c8e5b0d33a36d8046d42e9...

# %%
ds.centerCoords.plot()

# %%
cd /g/data/ik11/inputs/JRA-55/JRA55-do-1-5-0-1/mirror/atmos/3hrPt/uas/gr/latest
# Out:
# /g/data/ik11/inputs/JRA-55/JRA55-do-1-5-0-1/mirror/atmos/3hrPt/uas/gr/latest

# %%
ls
# Out:
# uas_input4MIPs_atmosphericState_OMIP_MRI-JRA55-do-1-5-0-1_gr_202101010000-202112312100.nc
# uas_input4MIPs_atmosphericState_OMIP_MRI-JRA55-do-1-5-0-1_gr_202201010000-202203312100.nc
# uas_input4MIPs_atmosphericState_OMIP_MRI-JRA55-do-1-5-0-1_gr_202201010000-202205082100.nc
# uas_input4MIPs_atmosphericState_OMIP_MRI-JRA55-do-1-5-0-1_gr_202201010000-202206252100.nc
# uas_input4MIPs_atmosphericState_OMIP_MRI-JRA55-do-1-5-0-1_gr_202201010000-202211032100.nc
# uas_input4MIPs_atmosphericState_OMIP_MRI-JRA55-do-1-5-0-1_gr_202201010000-202212312100.nc
# uas_input4MIPs_atmosphericState_OMIP_MRI-JRA55-do-1-5-0-1_gr_202301010000-202302112100.nc
# uas_input4MIPs_atmosphericState_OMIP_MRI-JRA55-do-1-5-0-1_gr_202301010000-202303092100.nc
# uas_input4MIPs_atmosphericState_OMIP_MRI-JRA55-do-1-5-0-1_gr_202301010000-202305102100.nc
# uas_input4MIPs_atmosphericState_OMIP_MRI-JRA55-do-1-5-0-1_gr_202301010000-202306292100.nc
# ...

# %%
ds = xr.open_dataset('uas_input4MIPs_atmosphericState_OMIP_MRI-JRA55-do-1-5-0-1_gr_202101010000-202112312100.nc')

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 2920, bnds: 2, lat: 320, lon: 640)
# Coordinates:
#   * time       (time) datetime64[ns] 2021-01-01 ... 2021-12-31T21:00:00
#   * lat        (lat) float64 -89.57 -89.01 -88.45 -87.89 ... 88.45 89.01 89.57
#   * lon        (lon) float64 0.0 0.5625 1.125 1.688 ... 357.8 358.3 358.9 359.4
#     height     float64 ...
# Dimensions without coordinates: bnds
# Data variables:
#     time_bnds  (time, bnds) datetime64[ns] ...
#     lat_bnds   (lat, bnds) float64 ...
#     lon_bnds   (lon, bnds) float64 ...
#     uas        (time, lat, lon) float32 ...
# Attributes: (12/36)
#     Conventions:         CF-1.7 CMIP-6.2
#     activity_id:         input4MIPs
#     cell_measures:       area: areacella
#     comment:             Based on JRA-55 reanalysis (1958-01 to latest)
#     contact:             Hiroyuki Tsujino (htsujino@mri-jma.go.jp)
#     creation_date:       2022-04-03T18:58:33Z
#     ...                  ...
#     target_mip:          OMIP
# ...

# %%
ds.uas.isel(time=0).plot()

# %%
ds=xr.open_dataset('/g/data/tm70/as2285/payu/MOM6-CICE6/archive/output002/GMOM_JRA.cpl.hx.ocn.24h.avg.1958-01-04-00000.nc')
# Out:
# 0.3.0

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:            (time: 1, ntb: 2, ocnImp_ny: 300, ocnImp_nx: 360)
# Coordinates:
#   * time               (time) datetime64[ns] 1958-01-03T12:00:00
# Dimensions without coordinates: ntb, ocnImp_ny, ocnImp_nx
# Data variables:
#     time_bnds          (time, ntb) float64 ...
#     ocnImp_So_bldepth  (time, ocnImp_ny, ocnImp_nx) float64 ...
#     ocnImp_So_t        (time, ocnImp_ny, ocnImp_nx) float64 ...
#     ocnImp_So_u        (time, ocnImp_ny, ocnImp_nx) float64 ...
#     ocnImp_So_v        (time, ocnImp_ny, ocnImp_nx) float64 ...
#     ocnImp_So_dhdx     (time, ocnImp_ny, ocnImp_nx) float64 ...
#     ocnImp_So_dhdy     (time, ocnImp_ny, ocnImp_nx) float64 ...
#     ocnImp_lon         (time, ocnImp_ny, ocnImp_nx) float64 ...
#     ocnImp_lat         (time, ocnImp_ny, ocnImp_nx) float64 ...
# Attributes:
#     file_version:   cmeps0
#     model_doi_url:  unset

# %%
ds['ocnImp_So_t'].plot(vmin=250)

# %%
ds = xr.open_dataset('/g/data/tm70/as2285/payu/MOM6-CICE6/archive/output001/GMOM_JRA.cpl.hx.ocn.24h.avg.1958-01-03-00000.nc')
# Out:
# 0.3.0

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:            (time: 1, ntb: 2, ocnImp_ny: 300, ocnImp_nx: 360)
# Coordinates:
#   * time               (time) datetime64[ns] 1958-01-02T12:00:00
# Dimensions without coordinates: ntb, ocnImp_ny, ocnImp_nx
# Data variables:
#     time_bnds          (time, ntb) float64 ...
#     ocnImp_So_bldepth  (time, ocnImp_ny, ocnImp_nx) float32 ...
#     ocnImp_So_t        (time, ocnImp_ny, ocnImp_nx) float32 0.0 0.0 ... 3.794
#     ocnImp_So_u        (time, ocnImp_ny, ocnImp_nx) float32 ...
#     ocnImp_So_v        (time, ocnImp_ny, ocnImp_nx) float32 ...
#     ocnImp_So_dhdx     (time, ocnImp_ny, ocnImp_nx) float32 ...
#     ocnImp_So_dhdy     (time, ocnImp_ny, ocnImp_nx) float32 ...
#     ocnImp_lon         (time, ocnImp_ny, ocnImp_nx) float32 ...
#     ocnImp_lat         (time, ocnImp_ny, ocnImp_nx) float32 ...
# Attributes:
#     file_version:   cmeps0
#     model_doi_url:  unset

# %%
(ds['ocnImp_So_t']==0).plot()

# %%
files = ! ls /g/data/tm70/as2285/payu/MOM6-CICE6/archive/output00*/GMOM_JRA.cice*

# %%
ds = xr.open_mfdataset(files)

# %%
ds

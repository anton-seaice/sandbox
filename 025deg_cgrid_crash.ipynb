#
#
# WARNING from PE  1036: btstep: eta has dropped below bathyT:  -1.8213097407123257E+01 vs.  -1.1805749893188477E+01 at  -1.9538E+02  5.8943E+01    340    793
#
#
# WARNING from PE  1036: btstep: eta has dropped below bathyT:  -1.7254352832592659E+01 vs.  -1.1805749893188477E+01 at  -1.9538E+02  5.8943E+01    340    793
#
#
# WARNING from PE  1017: btstep: eta has dropped below bathyT:  -3.6381439501032123E+03 vs.  -3.4612373046875000E+03 at  -1.9512E+02  5.8292E+01    341    788
#
#
# WARNING from PE  1017: btstep: eta has dropped below bathyT:  -8.2018608882184653E+03 vs.  -3.5232268066406250E+03 at  -1.9488E+02  5.8292E+01    342    788

# %%
sfc_files = !ls access-om3.mom6.h.sfc_1900_*

# %%
sfc_files
# Out:
# ['access-om3.mom6.h.sfc_1900_01.nc',
#  'access-om3.mom6.h.sfc_1900_02.nc',
#  'access-om3.mom6.h.sfc_1900_03.nc']

# %%
sfc_ds = xr.open_mfdataset(sfc_files)

# %%
sfc_ds
# Out:
# <xarray.Dataset> Size: 7GB
# Dimensions:       (time: 88, yh: 1080, xh: 1440, xq: 1440, yq: 1080, nv: 2)
# Coordinates:
#   * xh            (xh) float64 12kB -279.9 -279.6 -279.4 ... 79.38 79.62 79.88
#   * yh            (yh) float64 9kB -81.08 -80.97 -80.87 ... 89.74 89.84 89.95
#   * time          (time) object 704B 1900-01-01 12:00:00 ... 1900-03-29 12:00:00
#   * nv            (nv) float64 16B 1.0 2.0
#   * xq            (xq) float64 12kB -279.8 -279.5 -279.2 ... 79.5 79.75 80.0
#   * yq            (yq) float64 9kB -81.02 -80.92 -80.81 ... 89.79 89.89 90.0
# Data variables: (12/16)
#     SSH           (time, yh, xh) float32 547MB dask.array<chunksize=(1, 1080, 1440), meta=np.ndarray>
#     tos           (time, yh, xh) float32 547MB dask.array<chunksize=(1, 1080, 1440), meta=np.ndarray>
#     sos           (time, yh, xh) float32 547MB dask.array<chunksize=(1, 1080, 1440), meta=np.ndarray>
# ...

# %%
ax=plt.subplot()
plt.pcolor(sfc_ds['SSH'].isel(time=-2), cmap='coolwarm_r')
plt.colorbar()
ax.add_patch(plt.Rectangle((333,770),width=11, height=25, color='black', fill=None))

plt.xlim(100,500)
plt.ylim(600,900)
plt.title(f"{sfc_ds['SSH'].isel(time=-2).time.values} mean SSH")
# Out:
# /jobfs/125865318.gadi-pbs/ipykernel_530264/681911398.py:3: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   plt.colorbar()
# Text(0.5, 1.0, '1900-03-28 12:00:00 mean SSH')

# %%
ax=plt.subplot()
plt.pcolor(sfc_ds['SSH'].isel(time=-2), cmap='coolwarm_r')
plt.colorbar()
ax.add_patch(plt.Rectangle((333,770),width=11, height=25, color='black', fill=None))

plt.xlim(300,400)
plt.ylim(750,825)
plt.title(f"{sfc_ds['SSH'].isel(time=-2).time.values} mean SSH")
# Out:
# /jobfs/125865318.gadi-pbs/ipykernel_530264/3419059126.py:3: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   plt.colorbar()
# Text(0.5, 1.0, '1900-03-28 12:00:00 mean SSH')

# %%
sfc_ds['SSH'].isel(xh=332, yh=788).plot()

# %%
bathy_ds = xr.open_dataset('/g/data/vk83/configurations/inputs/access-om3/share/grids/global.025deg/2023.05.15/topog.nc')

# %%
bathy_ds
# Out:
# <xarray.Dataset> Size: 6MB
# Dimensions:  (ny: 1080, nx: 1440)
# Dimensions without coordinates: ny, nx
# Data variables:
#     depth    (ny, nx) float32 6MB ...
# Attributes:
#     history:   | Created on Mon May 15 13:42:57 AEST 2023 using https://githu...

# %%
ax=plt.subplot()
plt.pcolor(bathy_ds['depth'])
plt.colorbar()
ax.add_patch(plt.Rectangle((333,770),width=11, height=25, color='black', fill=None))

plt.xlim(100,500)
plt.ylim(600,900)
# Out:
# /jobfs/125865318.gadi-pbs/ipykernel_530264/630509037.py:3: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   plt.colorbar()
# (600.0, 900.0)

# %%
ax=plt.subplot()
plt.pcolor(bathy_ds['depth'])
plt.colorbar()
ax.add_patch(plt.Rectangle((333,770),width=11, height=25, color='red', fill=None))

plt.xlim(300,400)
plt.ylim(750,825)
# Out:
# /jobfs/125865318.gadi-pbs/ipykernel_530264/2135828407.py:3: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   plt.colorbar()
# (750.0, 825.0)

# %%
si_ds = xr.open_dataset('access-om3.cice.1900-03-28.nc')

ax=plt.subplot()
da=si_ds['aice'].isel(time=0)
plt.pcolor(da, cmap='Blues_r')
plt.colorbar()
ax.add_patch(plt.Rectangle((333,770),width=11, height=25, color='r', fill=None))

plt.xlim(100,500)
plt.ylim(600,900)
plt.title(f"{str(da.time.values)[0:10]} sea-ice conc")
# Out:
# /jobfs/125865318.gadi-pbs/ipykernel_530264/4084452349.py:6: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   plt.colorbar()
# Text(0.5, 1.0, '1900-03-28 sea-ice conc')

# %%
si_ds = xr.open_dataset('access-om3.cice.1900-02-28.nc')

ax=plt.subplot()
da=si_ds['aice'].isel(time=0)
plt.pcolor(da, cmap='Blues_r')
plt.colorbar()
ax.add_patch(plt.Rectangle((333,770),width=11, height=25, color='r', fill=None))

plt.xlim(100,500)
plt.ylim(600,900)
plt.title(f"{str(da.time.values)[0:10]} sea-ice conc")
# Out:
# /jobfs/125865318.gadi-pbs/ipykernel_530264/2882298750.py:6: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   plt.colorbar()
# Text(0.5, 1.0, '1900-02-28 sea-ice conc')

# %%
si_ds
# Out:
# <xarray.Dataset> Size: 535MB
# Dimensions:      (time: 1, nbnd: 2, nc: 5, nkice: 4, nksnow: 1, nkbio: 3,
#                   nkaer: 5, nj: 1080, ni: 1440)
# Coordinates:
#   * time         (time) object 8B 1900-02-28 12:00:00
# Dimensions without coordinates: nbnd, nc, nkice, nksnow, nkbio, nkaer, nj, ni
# Data variables: (12/49)
#     time_bounds  (time, nbnd) object 16B ...
#     NCAT         (nc) float64 40B ...
#     VGRDi        (nkice) float64 32B ...
#     VGRDs        (nksnow) float64 8B ...
#     VGRDb        (nkbio) float64 24B ...
#     VGRDa        (nkaer) float64 40B ...
#     ...           ...
#     strintyN     (time, nj, ni) float64 12MB ...
#     strintxE     (time, nj, ni) float64 12MB ...
#     strintyE     (time, nj, ni) float64 12MB ...
#     dvidtt       (time, nj, ni) float64 12MB ...
#     dvidtd       (time, nj, ni) float64 12MB ...
#     sifb         (time, nj, ni) float64 12MB ...
# Attributes:
#     title:               access-om3
# ...

# %%
si_ds.dvidtd.plot()
plt.xlim(300,400)
plt.ylim(750,825)
# Out:
# (750.0, 825.0)

# %%
si_daily_files = ! ls access-om3.cice.*

# %%
si_daily_files
# Out:
# ['access-om3.cice.1900-01-01.nc',
#  'access-om3.cice.1900-01-02.nc',
#  'access-om3.cice.1900-01-03.nc',
#  'access-om3.cice.1900-01-04.nc',
#  'access-om3.cice.1900-01-05.nc',
#  'access-om3.cice.1900-01-06.nc',
#  'access-om3.cice.1900-01-07.nc',
#  'access-om3.cice.1900-01-08.nc',
#  'access-om3.cice.1900-01-09.nc',
#  'access-om3.cice.1900-01-10.nc',
#  'access-om3.cice.1900-01-11.nc',
#  'access-om3.cice.1900-01-12.nc',
#  'access-om3.cice.1900-01-13.nc',
#  'access-om3.cice.1900-01-14.nc',
#  'access-om3.cice.1900-01-15.nc',
#  'access-om3.cice.1900-01-16.nc',
#  'access-om3.cice.1900-01-17.nc',
#  'access-om3.cice.1900-01-18.nc',
#  'access-om3.cice.1900-01-19.nc',
#  'access-om3.cice.1900-01-20.nc',
#  'access-om3.cice.1900-01-21.nc',
#  'access-om3.cice.1900-01-22.nc',
#  'access-om3.cice.1900-01-23.nc',
#  'access-om3.cice.1900-01-24.nc',
#  'access-om3.cice.1900-01-25.nc',
#  'access-om3.cice.1900-01-26.nc',
#  'access-om3.cice.1900-01-27.nc',
# ...

# %%
from dask.distributed import Client

# %%
client = Client(threads_per_worker=1)

# %%
client
# Out:
# <Client: 'tcp://127.0.0.1:37885' processes=4 threads=4, memory=15.00 GiB>

# %%
si_daily_ds = xr.open_mfdataset(si_daily_files, compat='override', coords='minimal')

# %%
si_daily_ds
# Out:
# <xarray.Dataset> Size: 47GB
# Dimensions:      (time: 88, nbnd: 2, nc: 5, nkice: 4, nksnow: 1, nkbio: 3,
#                   nkaer: 5, nj: 1080, ni: 1440)
# Coordinates:
#   * time         (time) object 704B 1900-01-01 12:00:00 ... 1900-03-29 12:00:00
# Dimensions without coordinates: nbnd, nc, nkice, nksnow, nkbio, nkaer, nj, ni
# Data variables: (12/49)
#     time_bounds  (time, nbnd) object 1kB dask.array<chunksize=(1, 2), meta=np.ndarray>
#     NCAT         (time, nc) float64 4kB dask.array<chunksize=(1, 5), meta=np.ndarray>
#     VGRDi        (time, nkice) float64 3kB dask.array<chunksize=(1, 4), meta=np.ndarray>
#     VGRDs        (time, nksnow) float64 704B dask.array<chunksize=(1, 1), meta=np.ndarray>
#     VGRDb        (time, nkbio) float64 2kB dask.array<chunksize=(1, 3), meta=np.ndarray>
#     VGRDa        (time, nkaer) float64 4kB dask.array<chunksize=(1, 5), meta=np.ndarray>
#     ...           ...
# ...

# %%
si_daily_ds.hi.isel(ni=332, nj=788).plot()

# %%
si_daily_ds.vice.isel(ni=332, nj=788).plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[111], line 1
# ----> 1 si_daily_ds.vice.isel(ni=332, nj=788).plot()
#
# File /g/data/hh5/public/apps/miniconda3/envs/analysis3-24.04/lib/python3.10/site-packages/xarray/core/common.py:285, in AttrAccessMixin.__getattr__(self, name)
#     283         with suppress(KeyError):
#     284             return source[name]
# --> 285 raise AttributeError(
#     286     f"{type(self).__name__!r} object has no attribute {name!r}"
#     287 )
#
# AttributeError: 'Dataset' object has no attribute 'vice'

# %%
si_daily_ds.dvidtt.isel(ni=332, nj=788).plot()

# %%
import xarray as xr
import matplotlib.pyplot as plt

# %%
cd /scratch/tm70/as2285/access-om3/work/dev-025deg_jra55do_ryf-cgrid-dev-025deg_jra55do_ryf-cgrid-fdc63cf8
# Out:
# /scratch/tm70/as2285/access-om3/work/dev-025deg_jra55do_ryf-cgrid-dev-025deg_jra55do_ryf-cgrid-fdc63cf8

# %%
ls
# Out:
# access-om3.cice.1900-04-01.nc             available_diags.000000
# access-om3.cice.1900-04-02.nc             config.yaml
# access-om3.cice.1900-04-03.nc             datm_in
# access-om3.cice.1900-04-04.nc             datm.streams.xml
# access-om3.cice.1900-04-05.nc             diag_table
# access-om3.cice.1900-04-06.nc             drof_in
# access-om3.cice.1900-04-07.nc             drof.streams.xml
# access-om3.cice.1900-04-08.nc             drv_in
# access-om3.cice.1900-04-09.nc             fd.yaml
# access-om3.cice.1900-04-10.nc             ice_in
# access-om3.cice.1900-04-11.nc             INPUT/
# access-om3.cice.1900-04-12.nc             input.nml
# access-om3.cice.1900-04-13.nc             log/
# access-om3.cice.1900-04-14.nc             logfile.000000.out
# access-om3.cice.1900-04-15.nc             manifests/
# access-om3.cice.r.1900-04-01-00000.nc     MOM_auto_mask_table
# access-om3.cpl.r.1900-04-01-00000.nc@     MOM_IC_1.nc
# ...

# %% [raw]
# WARNING from PE  1036: btstep: eta has dropped below bathyT:  -1.1830195374307833E+01 vs.  -1.1805749893188477E+01 at  -1.9538E+02  5.8943E+01    340    793
#
#
# WARNING from PE  1036: btstep: eta has dropped below bathyT:  -1.1883078544376472E+01 vs.  -1.1805749893188477E+01 at  -1.9538E+02  5.8943E+01    340    793
#
#
# WARNING from PE  1036: btstep: eta has dropped below bathyT:  -1.2629411131060746E+01 vs.  -1.1805749893188477E+01 at  -1.9538E+02  5.8943E+01    340    793
#
#
# WARNING from PE  1036: btstep: eta has dropped below bathyT:  -1.2635726750105537E+01 vs.  -1.1805749893188477E+01 at  -1.9538E+02  5.8943E+01    340    793
#
#
# FATAL from PE  1200: write_energy : Ocean velocity has been truncated too many times.
#
#
# FATAL from PE    48: write_energy : Ocean velocity has been truncated too many times.
#
#
# FATAL from PE   576: write_energy : Ocean velocity has been truncated too many times.
#
#
# FATAL from PE   192: write_energy : Ocean velocity has been truncated too many times.

# %%
sfc_files = !ls access-om3.mom6.h.sfc_1900_*

# %%
sfc_files
# Out:
# ['access-om3.mom6.h.sfc_1900_04_01.nc',
#  'access-om3.mom6.h.sfc_1900_04_02.nc',
#  'access-om3.mom6.h.sfc_1900_04_03.nc',
#  'access-om3.mom6.h.sfc_1900_04_04.nc',
#  'access-om3.mom6.h.sfc_1900_04_05.nc',
#  'access-om3.mom6.h.sfc_1900_04_06.nc',
#  'access-om3.mom6.h.sfc_1900_04_07.nc',
#  'access-om3.mom6.h.sfc_1900_04_08.nc',
#  'access-om3.mom6.h.sfc_1900_04_09.nc',
#  'access-om3.mom6.h.sfc_1900_04_10.nc',
#  'access-om3.mom6.h.sfc_1900_04_11.nc',
#  'access-om3.mom6.h.sfc_1900_04_12.nc',
#  'access-om3.mom6.h.sfc_1900_04_13.nc',
#  'access-om3.mom6.h.sfc_1900_04_14.nc']

# %%
sfc_ds = xr.open_mfdataset(sfc_files)

# %%
sfc_ds
# Out:
# <xarray.Dataset> Size: 1GB
# Dimensions:       (time: 14, yh: 1080, xh: 1440, xq: 1440, yq: 1080, nv: 2)
# Coordinates:
#   * xh            (xh) float64 12kB -279.9 -279.6 -279.4 ... 79.38 79.62 79.88
#   * yh            (yh) float64 9kB -81.08 -80.97 -80.87 ... 89.74 89.84 89.95
#   * time          (time) object 112B 1900-04-01 12:00:00 ... 1900-04-14 12:00:00
#   * nv            (nv) float64 16B 1.0 2.0
#   * xq            (xq) float64 12kB -279.8 -279.5 -279.2 ... 79.5 79.75 80.0
#   * yq            (yq) float64 9kB -81.02 -80.92 -80.81 ... 89.79 89.89 90.0
# Data variables: (12/16)
#     SSH           (time, yh, xh) float32 87MB dask.array<chunksize=(1, 1080, 1440), meta=np.ndarray>
#     tos           (time, yh, xh) float32 87MB dask.array<chunksize=(1, 1080, 1440), meta=np.ndarray>
#     sos           (time, yh, xh) float32 87MB dask.array<chunksize=(1, 1080, 1440), meta=np.ndarray>
# ...

# %%
sfc_ds['SSH'].isel(xh=338, yh=791).xh.values
# Out:
# array(-195.375)

# %%
sfc_ds['SSH'].isel(xh=338, yh=791).yh.values
# Out:
# array(58.94299691)

# %%
i=338
j=791

# %%
sfc_ds.isel(xq=339, yq=792)
# Out:
# <xarray.Dataset> Size: 871MB
# Dimensions:       (time: 14, yh: 1080, xh: 1440, nv: 2)
# Coordinates:
#   * xh            (xh) float64 12kB -279.9 -279.6 -279.4 ... 79.38 79.62 79.88
#   * yh            (yh) float64 9kB -81.08 -80.97 -80.87 ... 89.74 89.84 89.95
#   * time          (time) object 112B 1900-04-01 12:00:00 ... 1900-04-14 12:00:00
#   * nv            (nv) float64 16B 1.0 2.0
#     xq            float64 8B -195.0
#     yq            float64 8B 59.14
# Data variables: (12/16)
#     SSH           (time, yh, xh) float32 87MB dask.array<chunksize=(1, 1080, 1440), meta=np.ndarray>
#     tos           (time, yh, xh) float32 87MB dask.array<chunksize=(1, 1080, 1440), meta=np.ndarray>
#     sos           (time, yh, xh) float32 87MB dask.array<chunksize=(1, 1080, 1440), meta=np.ndarray>
#     SSU           (time, yh) float32 60kB dask.array<chunksize=(1, 1080), meta=np.ndarray>
#     SSV           (time, xh) float32 81kB dask.array<chunksize=(1, 1440), meta=np.ndarray>
# ...

# %%
ax=plt.subplot()
plt.pcolor(sfc_ds['SSH'].isel(time=-2), cmap='coolwarm_r')
plt.colorbar()
ax.add_patch(plt.Rectangle((333,770),width=11, height=25, color='black', fill=None))

plt.xlim(100,500)
plt.ylim(600,900)
plt.title(f"{sfc_ds['SSH'].isel(time=-2).time.values} mean SSH")
# Out:
# /jobfs/126889167.gadi-pbs/ipykernel_1547399/681911398.py:3: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   plt.colorbar()
# Text(0.5, 1.0, '1900-04-13 12:00:00 mean SSH')

# %%
ax=plt.subplot()
plt.pcolor(sfc_ds['SSH'].isel(time=-2), cmap='coolwarm_r')
plt.colorbar()
ax.add_patch(plt.Rectangle((333,770),width=11, height=25, color='black', fill=None))

plt.xlim(300,400)
plt.ylim(750,825)
plt.title(f"{sfc_ds['SSH'].isel(time=-2).time.values} mean SSH")
# Out:
# /jobfs/126889167.gadi-pbs/ipykernel_1547399/3419059126.py:3: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   plt.colorbar()
# Text(0.5, 1.0, '1900-04-13 12:00:00 mean SSH')

# %%
ax=plt.subplot()
plt.pcolor(sfc_ds['SSU'].isel(time=-2), cmap='coolwarm_r')
plt.colorbar()
ax.add_patch(plt.Rectangle((333,770),width=11, height=25, color='black', fill=None))
ax.add_patch(plt.Rectangle((i-1,j-1),width=3, height=3, color='orange', fill=None))

plt.xlim(300,400)
plt.ylim(750,825)
plt.title(f"{sfc_ds['SSU'].isel(time=-2).time.values} mean SSU")
# Out:
# /jobfs/126889167.gadi-pbs/ipykernel_1547399/1680304050.py:3: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   plt.colorbar()
# Text(0.5, 1.0, '1900-04-13 12:00:00 mean SSU')

# %%
ax=plt.subplot()
plt.pcolor(sfc_ds['SSV'].isel(time=-2), cmap='coolwarm_r')
plt.colorbar()
ax.add_patch(plt.Rectangle((333,770),width=11, height=25, color='black', fill=None))
ax.add_patch(plt.Rectangle((i-1,j-1),width=3, height=3, color='orange', fill=None))

plt.xlim(300,400)
plt.ylim(750,825)
plt.title(f"{sfc_ds['SSV'].isel(time=-2).time.values} mean SSU")
# Out:
# /jobfs/126889167.gadi-pbs/ipykernel_1547399/2934683855.py:3: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   plt.colorbar()
# Text(0.5, 1.0, '1900-04-13 12:00:00 mean SSU')

# %%
sfc_ds['SSH'].isel(xh=338, yh=791).plot()

# %%
bathy_ds = xr.open_dataset('/g/data/vk83/configurations/inputs/access-om3/share/grids/global.025deg/2023.05.15/topog.nc')

# %%
bathy_ds
# Out:
# <xarray.Dataset> Size: 6MB
# Dimensions:  (ny: 1080, nx: 1440)
# Dimensions without coordinates: ny, nx
# Data variables:
#     depth    (ny, nx) float32 6MB ...
# Attributes:
#     history:   | Created on Mon May 15 13:42:57 AEST 2023 using https://githu...

# %%
ax=plt.subplot()
plt.pcolor(bathy_ds['depth'])
plt.colorbar()
ax.add_patch(plt.Rectangle((333,770),width=11, height=25, color='black', fill=None))

plt.xlim(100,500)
plt.ylim(600,900)
# Out:
# /jobfs/126889167.gadi-pbs/ipykernel_1547399/630509037.py:3: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   plt.colorbar()
# (600.0, 900.0)

# %%
ax=plt.subplot()
plt.pcolor(bathy_ds['depth'])
plt.colorbar()
ax.add_patch(plt.Rectangle((333,770),width=11, height=25, color='red', fill=None))
ax.add_patch(plt.Rectangle((i-1,j-1),width=3, height=3, color='orange', fill=None))

plt.xlim(300,400)
plt.ylim(750,825)
# Out:
# /jobfs/126889167.gadi-pbs/ipykernel_1547399/3937679211.py:3: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   plt.colorbar()
# (750.0, 825.0)

# %%
si_ds = xr.open_dataset('access-om3.cice.1900-04-14.nc')

ax=plt.subplot()
da=si_ds['aice'].isel(time=0)
plt.pcolor(da, cmap='Blues_r')
plt.colorbar()
ax.add_patch(plt.Rectangle((333,770),width=11, height=25, color='r', fill=None))

plt.xlim(100,500)
plt.ylim(600,900)
plt.title(f"{str(da.time.values)[0:10]} sea-ice conc")
# Out:
# /jobfs/126889167.gadi-pbs/ipykernel_1547399/2199656458.py:6: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   plt.colorbar()
# Text(0.5, 1.0, '1900-04-14 sea-ice conc')

# %%
si_ds
# Out:
# <xarray.Dataset> Size: 535MB
# Dimensions:      (time: 1, nbnd: 2, nc: 5, nkice: 4, nksnow: 1, nkbio: 3,
#                   nkaer: 5, nj: 1080, ni: 1440)
# Coordinates:
#   * time         (time) object 8B 1900-04-14 12:00:00
# Dimensions without coordinates: nbnd, nc, nkice, nksnow, nkbio, nkaer, nj, ni
# Data variables: (12/49)
#     time_bounds  (time, nbnd) object 16B ...
#     NCAT         (nc) float64 40B ...
#     VGRDi        (nkice) float64 32B ...
#     VGRDs        (nksnow) float64 8B ...
#     VGRDb        (nkbio) float64 24B ...
#     VGRDa        (nkaer) float64 40B ...
#     ...           ...
#     strintyN     (time, nj, ni) float64 12MB ...
#     strintxE     (time, nj, ni) float64 12MB ...
#     strintyE     (time, nj, ni) float64 12MB ...
#     dvidtt       (time, nj, ni) float64 12MB ...
#     dvidtd       (time, nj, ni) float64 12MB ...
#     sifb         (time, nj, ni) float64 12MB ...
# Attributes:
#     title:               access-om3
# ...

# %%
si_ds.dvidtd.plot()
plt.xlim(300,400)
plt.ylim(750,825)
# Out:
# (750.0, 825.0)

# %%
si_daily_files = ! ls access-om3.cice.*

# %%
si_daily_files
# Out:
# ['access-om3.cice.1900-04-01.nc',
#  'access-om3.cice.1900-04-02.nc',
#  'access-om3.cice.1900-04-03.nc',
#  'access-om3.cice.1900-04-04.nc',
#  'access-om3.cice.1900-04-05.nc',
#  'access-om3.cice.1900-04-06.nc',
#  'access-om3.cice.1900-04-07.nc',
#  'access-om3.cice.1900-04-08.nc',
#  'access-om3.cice.1900-04-09.nc',
#  'access-om3.cice.1900-04-10.nc',
#  'access-om3.cice.1900-04-11.nc',
#  'access-om3.cice.1900-04-12.nc',
#  'access-om3.cice.1900-04-13.nc',
#  'access-om3.cice.1900-04-14.nc',
#  'access-om3.cice.1900-04-15.nc',
#  'access-om3.cice.r.1900-04-01-00000.nc']

# %%
from dask.distributed import Client

# %%
client = Client(threads_per_worker=1)

# %%
client
# Out:
# <Client: 'tcp://127.0.0.1:34827' processes=4 threads=4, memory=15.00 GiB>

# %%
si_daily_ds = xr.open_mfdataset(si_daily_files[:-2], compat='override', coords='minimal')

# %%
si_daily_ds
# Out:
# <xarray.Dataset> Size: 7GB
# Dimensions:      (time: 14, nbnd: 2, nc: 5, nkice: 4, nksnow: 1, nkbio: 3,
#                   nkaer: 5, nj: 1080, ni: 1440)
# Coordinates:
#   * time         (time) object 112B 1900-04-01 12:00:00 ... 1900-04-14 12:00:00
# Dimensions without coordinates: nbnd, nc, nkice, nksnow, nkbio, nkaer, nj, ni
# Data variables: (12/49)
#     time_bounds  (time, nbnd) object 224B dask.array<chunksize=(1, 2), meta=np.ndarray>
#     NCAT         (time, nc) float64 560B dask.array<chunksize=(1, 5), meta=np.ndarray>
#     VGRDi        (time, nkice) float64 448B dask.array<chunksize=(1, 4), meta=np.ndarray>
#     VGRDs        (time, nksnow) float64 112B dask.array<chunksize=(1, 1), meta=np.ndarray>
#     VGRDb        (time, nkbio) float64 336B dask.array<chunksize=(1, 3), meta=np.ndarray>
#     VGRDa        (time, nkaer) float64 560B dask.array<chunksize=(1, 5), meta=np.ndarray>
#     ...           ...
# ...

# %%
si_daily_ds.hi.isel(ni=i, nj=j).plot()

# %%
si_daily_ds.aice.isel(ni=i, nj=j).plot()

# %%
si_daily_ds.dvidtt.isel(ni=i, nj=j).plot()

# %%
to_plot = si_daily_ds.isel(time=-2).load()

# %%
ax=plt.subplot()
plt.pcolor(to_plot['aice'])
plt.colorbar()
ax.add_patch(plt.Rectangle((333,770),width=11, height=25, color='red', fill=None))
ax.add_patch(plt.Rectangle((i-1,j-1),width=3, height=3, color='orange', fill=None))


plt.quiver(
    to_plot.uvel, to_plot.vvel
)

plt.xlim(300,400)
plt.ylim(750,825)
# Out:
# /jobfs/126889167.gadi-pbs/ipykernel_1547399/1822413585.py:3: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   plt.colorbar()
# (750.0, 825.0)

# %%
plt.quiver(
    to_plot.uvel, to_plot.vvel, scale=5
)

plt.xlim(300,400)
plt.ylim(750,825)
# Out:
# (750.0, 825.0)

# %%
import numpy as np

# %%
xr.apply_ufunc(np.hypot, to_plot.uvel, to_plot.vvel).plot()

plt.xlim(300,400)
plt.ylim(750,825)
# Out:
# (750.0, 825.0)

# %%
plt.quiver(
    to_plot.uvelN, to_plot.vvelN, scale=5
)

plt.xlim(300,400)
plt.ylim(750,825)
# Out:
# (750.0, 825.0)

# %%
plt.quiver(
    to_plot.uvelE, to_plot.vvelE, scale=5
)

plt.xlim(300,400)
plt.ylim(750,825)
# Out:
# (750.0, 825.0)

# %%
client.close()

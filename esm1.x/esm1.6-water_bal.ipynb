# %%
import xarray as xr

import numpy as np

import matplotlib.pyplot as plt

# %%
from dask.distributed import Client

# %%
client.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 client.close()
#
# NameError: name 'client' is not defined

# %%
client = Client(threads_per_worker = 1)

# %%
client
# Out:
# <Client: 'tcp://127.0.0.1:39505' processes=12 threads=12, memory=46.00 GiB>

# %%
CICE4 = '/scratch/p66/pjb581/access-esm/archive/pi_concentrations-expt-c55f7217/output0[0-1][0-9]/'
#'/g/data/tm70/as2285/payu/esm1.6-preind-cice4/archive/output0[0-9][0-9]/'
CICE5 = '/g/data/tm70/as2285/payu/esm1.6-preind+c-cice5+om2_ic/archive/output0[0-9][0-9]/'
#'/g/data/tm70/as2285/payu/esm1.6-preind+c-cice5+lprec0/archive/output0[0-9][0-9]/'
CICE5_sal4 = '/g/data/tm70/as2285/payu/esm1.6-preind+c-cice5+sal4_ocnF/archive/output0[0-9][0-9]/'

# %%
cice4 = xr.open_mfdataset(CICE4+'ocean/ocean-scalar-1monthly-ym_0*.nc').load()
# Out:
# /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/xarray/coding/times.py:1001: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/xarray/core/indexing.py:516: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   return np.asarray(self.get_duck_array(), dtype=dtype)
# /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/xarray/coding/times.py:1001: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
# ...

# %%
cice5 = xr.open_mfdataset(CICE5_sal4+'ocean/ocean-scalar-1monthly-ym_0*.nc').load()
# Out:
# /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/xarray/coding/times.py:1001: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/xarray/core/indexing.py:516: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   return np.asarray(self.get_duck_array(), dtype=dtype)
# /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/xarray/coding/times.py:1001: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
# ...

# %%
cice4
# Out:
# <xarray.Dataset> Size: 38kB
# Dimensions:                      (time: 240, scalar_axis: 1, nv: 2)
# Coordinates:
#   * scalar_axis                  (scalar_axis) float64 8B 0.0
#   * time                         (time) object 2kB 0101-01-15 12:00:00 ... 01...
#   * nv                           (nv) float64 16B 1.0 2.0
# Data variables: (12/32)
#     total_mass_seawater          (time, scalar_axis) float32 960B 1.335e+21 ....
#     total_volume_seawater        (time, scalar_axis) float32 960B 1.29e+18 .....
#     eta_global                   (time, scalar_axis) float32 960B -3.772 ... ...
#     eta_adjust                   (time, scalar_axis) float32 960B 1.225e-06 ....
#     pbot_adjust                  (time, scalar_axis) float32 960B 1.245e-06 ....
#     temp_global_ave              (time, scalar_axis) float32 960B 4.278 ... 4...
#     ...                           ...
#     temp_surface_ave             (time, scalar_axis) float32 960B 18.93 ... 1...
# ...

# %%
for iVar in list(cice4.data_vars)[:-4]:
    for i in [cice4,cice5]:
        i[iVar].plot()
    plt.show()

# %% [markdown]
# #### ocn_scalar.isel(run=1).data_vars

# %%
list(ocn_scalar.isel(run=1).data_vars)

# %%
cice4 = xr.open_mfdataset(CICE4+'ocean/ocean-2d-sfc_salt_flux_ice*').load()
# Out:
# /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/xarray/coding/times.py:1001: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/xarray/core/indexing.py:516: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   return np.asarray(self.get_duck_array(), dtype=dtype)
# /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/xarray/coding/times.py:1001: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
# ...

# %%
cice5 = xr.open_mfdataset(CICE5_sal4+'ocean/ocean-2d-sfc_salt_flux_ice*').load()
# Out:
# /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/xarray/coding/times.py:1001: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/xarray/core/indexing.py:516: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   return np.asarray(self.get_duck_array(), dtype=dtype)
# /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/xarray/coding/times.py:1001: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
# ...

# %%
cice4.sfc_salt_flux_ice.sum(['xt_ocean','yt_ocean']).plot()
cice5.sfc_salt_flux_ice.sum(['xt_ocean','yt_ocean']).plot()

# %%
cice4 = xr.open_mfdataset(CICE4+'ocean/ocean-2d-sfc_salt_flux_runoff*').load()

cice5 = xr.open_mfdataset(CICE5_sal4+'ocean/ocean-2d-sfc_salt_flux_runoff*').load()

# %%
cice4

# %%
cice4.sfc_salt_flux_runoff.sum(['xt_ocean','yt_ocean']).plot()
cice5.sfc_salt_flux_runoff.sum(['xt_ocean','yt_ocean']).plot()

# %%
cice4.sfc_salt_flux_runoff.isel(time=0).plot()

# %%
cice4 = xr.open_mfdataset(CICE4+'ocean/ocean-2d-river*').load()

cice5 = xr.open_mfdataset(CICE5_sal4+'ocean/ocean-2d-river*').load()

# %%
cice4

# %%
cice4.river.sum(['xt_ocean','yt_ocean']).plot()
cice5.river.sum(['xt_ocean','yt_ocean']).plot()

# %%
cice4_mlt = xr.open_mfdataset(CICE4+'ocean/ocean-2d-wfimelt*').load()
cice5_mlt = xr.open_mfdataset(CICE5_sal4+'ocean/ocean-2d-wfimelt*').load()
# Out:
# /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/xarray/coding/times.py:1001: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/xarray/core/indexing.py:516: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   return np.asarray(self.get_duck_array(), dtype=dtype)
# /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/xarray/coding/times.py:1001: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
# ...

# %%
cice4_mlt.wfimelt.sum(['xt_ocean','yt_ocean']).plot()
cice5_mlt.wfimelt.sum(['xt_ocean','yt_ocean']).plot()

# %%
cice4_mlt.wfimelt.sum(['xt_ocean','yt_ocean']).resample({'time':'YE'}).mean().plot()
cice5_mlt.wfimelt.sum(['xt_ocean','yt_ocean']).resample({'time':'YE'}).mean().plot()

# %%
cice4_form = xr.open_mfdataset(CICE4+'ocean/ocean-2d-wfiform*').load()
cice5_form = xr.open_mfdataset(CICE5_sal4+'ocean/ocean-2d-wfiform*').load()
# Out:
# /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/xarray/coding/times.py:1001: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/xarray/core/indexing.py:516: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   return np.asarray(self.get_duck_array(), dtype=dtype)
# /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/xarray/coding/times.py:1001: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
# ...

# %%
cice4_form.wfiform.sum(['xt_ocean','yt_ocean']).plot()
cice5_form.wfiform.sum(['xt_ocean','yt_ocean']).plot()

# %%
areas = xr.open_dataset('/g/data/tm70/as2285/payu/esm1.6-preind+c-cice5+om2_ic/archive/output000/ocean/ocean-2d-area_t.nc')
# Out:
# /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/xarray/coding/times.py:1001: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /g/data/xp65/public/apps/med_conda/envs/analysis3-24.07/lib/python3.11/site-packages/xarray/core/indexing.py:516: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   return np.asarray(self.get_duck_array(), dtype=dtype)

# %%
tarea = areas.drop('time').area_t
# Out:
# /jobfs/140610397.gadi-pbs/ipykernel_891127/381599481.py:1: DeprecationWarning: dropping variables using `drop` is deprecated; use drop_vars.
#   tarea = areas.drop('time').area_t

# %%
tarea
# Out:
# <xarray.DataArray 'area_t' (yt_ocean: 300, xt_ocean: 360)> Size: 432kB
# [108000 values with dtype=float32]
# Coordinates:
#   * xt_ocean  (xt_ocean) float64 3kB -279.5 -278.5 -277.5 ... 77.5 78.5 79.5
#   * yt_ocean  (yt_ocean) float64 2kB -77.88 -77.63 -77.38 ... 88.87 89.32 89.77
# Attributes:
#     long_name:     tracer cell area
#     units:         m^2
#     valid_range:   [0.e+00 1.e+15]
#     cell_methods:  time: point

# %%
(cice4_form.wfiform*tarea).sum(['xt_ocean','yt_ocean']).resample({'time':'YE'}).mean().plot()
(cice5_form.wfiform*tarea).sum(['xt_ocean','yt_ocean']).resample({'time':'YE'}).mean().plot()

# %%
((cice4_mlt.wfimelt+cice4_form.wfiform)*tarea*30.4*24*60*60).sum(['xt_ocean','yt_ocean']).resample({'time':'YE'}).sum().plot()
((cice5_mlt.wfimelt+cice5_form.wfiform)*tarea*30.4*24*60*60).sum(['xt_ocean','yt_ocean']).resample({'time':'YE'}).sum().plot()

# %%
cice4_mlt
# Out:
# <xarray.Dataset> Size: 518MB
# Dimensions:     (time: 1200, yt_ocean: 300, xt_ocean: 360, nv: 2)
# Coordinates:
#   * xt_ocean    (xt_ocean) float64 3kB -279.5 -278.5 -277.5 ... 77.5 78.5 79.5
#   * yt_ocean    (yt_ocean) float64 2kB -77.88 -77.63 -77.38 ... 89.32 89.77
#   * time        (time) object 10kB 0101-01-15 12:00:00 ... 0200-12-14 12:00:00
#   * nv          (nv) float64 16B 1.0 2.0
# Data variables:
#     wfimelt     (time, yt_ocean, xt_ocean) float32 518MB nan nan nan ... nan nan
#     average_T1  (time) object 10kB 0100-12-31 00:00:00 ... 0200-11-29 00:00:00
#     average_T2  (time) object 10kB 0101-01-31 00:00:00 ... 0200-12-30 00:00:00
#     average_DT  (time) timedelta64[ns] 10kB 31 days 28 days ... 30 days 31 days
#     time_bnds   (time, nv) timedelta64[ns] 19kB 36524 days ... 73048 days
# Attributes:
#     filename:   ocean-2d-wfimelt-1monthly-mean-ym_0101_01.nc
#     title:      ACCESS-ESM_CMIP6
#     grid_type:  regular
#     grid_tile:  N/A

# %%
cice4_form
# Out:
# <xarray.Dataset> Size: 518MB
# Dimensions:     (time: 1200, yt_ocean: 300, xt_ocean: 360, nv: 2)
# Coordinates:
#   * xt_ocean    (xt_ocean) float64 3kB -279.5 -278.5 -277.5 ... 77.5 78.5 79.5
#   * yt_ocean    (yt_ocean) float64 2kB -77.88 -77.63 -77.38 ... 89.32 89.77
#   * time        (time) object 10kB 0101-01-15 12:00:00 ... 0200-12-14 12:00:00
#   * nv          (nv) float64 16B 1.0 2.0
# Data variables:
#     wfiform     (time, yt_ocean, xt_ocean) float32 518MB nan nan nan ... nan nan
#     average_T1  (time) object 10kB 0100-12-31 00:00:00 ... 0200-11-29 00:00:00
#     average_T2  (time) object 10kB 0101-01-31 00:00:00 ... 0200-12-30 00:00:00
#     average_DT  (time) timedelta64[ns] 10kB 31 days 28 days ... 30 days 31 days
#     time_bnds   (time, nv) timedelta64[ns] 19kB 36524 days ... 73048 days
# Attributes:
#     filename:   ocean-2d-wfiform-1monthly-mean-ym_0101_01.nc
#     title:      ACCESS-ESM_CMIP6
#     grid_type:  regular
#     grid_tile:  N/A

# %%
tarea
# Out:
# <xarray.DataArray 'area_t' (yt_ocean: 300, xt_ocean: 360)> Size: 432kB
# array([[6.409530e+08, 6.409530e+08, 6.409530e+08, ..., 6.409530e+08,
#         6.409530e+08, 6.409530e+08],
#        [6.554656e+08, 6.554656e+08, 6.554656e+08, ..., 6.554656e+08,
#         6.554656e+08, 6.554656e+08],
#        [6.717785e+08, 6.717785e+08, 6.717785e+08, ..., 6.717785e+08,
#         6.717785e+08, 6.717785e+08],
#        ...,
#        [3.850424e+07, 1.119734e+08, 1.809739e+08, ..., 1.809739e+08,
#         1.119734e+08, 3.850424e+07],
#        [3.854668e+07, 1.120882e+08, 1.811460e+08, ..., 1.811460e+08,
#         1.120882e+08, 3.854668e+07],
#        [3.856794e+07, 1.121457e+08, 1.812321e+08, ..., 1.812321e+08,
#         1.121457e+08, 3.856794e+07]], dtype=float32)
# Coordinates:
#   * xt_ocean  (xt_ocean) float64 3kB -279.5 -278.5 -277.5 ... 77.5 78.5 79.5
#   * yt_ocean  (yt_ocean) float64 2kB -77.88 -77.63 -77.38 ... 88.87 89.32 89.77
# Attributes:
#     long_name:     tracer cell area
# ...

# %%
cice4_mlt.wfimelt
# Out:
# <xarray.DataArray 'wfimelt' (time: 1200, yt_ocean: 300, xt_ocean: 360)> Size: 518MB
# array([[[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
# ...
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
# ...
